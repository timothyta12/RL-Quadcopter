# %% [markdown]
# # Project: Train a Quadcopter How to Fly
#
# Design an agent to fly a quadcopter, and then train it using a reinforcement learning algorithm of your choice!
#
# Try to apply the techniques you have learnt, but also feel free to come up with innovative ideas and test them.

# %% [markdown]
# ## Instructions
#
# Take a look at the files in the directory to better understand the structure of the project.
#
# - `task.py`: Define your task (environment) in this file.
# - `agents/`: Folder containing reinforcement learning agents.
#     - `policy_search.py`: A sample agent has been provided here.
#     - `agent.py`: Develop your agent here.
# - `physics_sim.py`: This file contains the simulator for the quadcopter.  **DO NOT MODIFY THIS FILE**.
#
# For this project, you will define your own task in `task.py`.  Although we have provided a example task to get you started, you are encouraged to change it.  Later in this notebook, you will learn more about how to amend this file.
#
# You will also design a reinforcement learning agent in `agent.py` to complete your chosen task.
#
# You are welcome to create any additional files to help you to organize your code.  For instance, you may find it useful to define a `model.py` file defining any needed neural network architectures.
#
# ## Controlling the Quadcopter
#
# We provide a sample agent in the code cell below to show you how to use the sim to control the quadcopter.  This agent is even simpler than the sample agent that you'll examine (in `agents/policy_search.py`) later in this notebook!
#
# The agent controls the quadcopter by setting the revolutions per second on each of its four rotors.  The provided agent in the `Basic_Agent` class below always selects a random action for each of the four rotors.  These four speeds are returned by the `act` method as a list of four floating-point numbers.
#
# For this project, the agent that you will implement in `agents/agent.py` will have a far more intelligent method for selecting actions!

# %%
import random

class Basic_Agent():
    def __init__(self, task):
        self.task = task
    
    def act(self):
        new_thrust = random.gauss(450., 25.)
        return [new_thrust + random.gauss(0., 1.) for x in range(4)]

# %% [markdown]
# Run the code cell below to have the agent select actions to control the quadcopter.
#
# Feel free to change the provided values of `runtime`, `init_pose`, `init_velocities`, and `init_angle_velocities` below to change the starting conditions of the quadcopter.
#
# The `labels` list below annotates statistics that are saved while running the simulation.  All of this information is saved in a text file `data.txt` and stored in the dictionary `results`.

# %%
# %load_ext autoreload
# %autoreload 2

import csv
import numpy as np
from task import Task

# Modify the values below to give the quadcopter a different starting position.
runtime = 5.                                     # time limit of the episode
init_pose = np.array([0., 0., 10., 0., 0., 0.])  # initial pose
init_velocities = np.array([0., 0., 0.])         # initial velocities
init_angle_velocities = np.array([0., 0., 0.])   # initial angle velocities
file_output = 'data.txt'                         # file name for saved results

# Setup
task = Task(init_pose, init_velocities, init_angle_velocities, runtime)
agent = Basic_Agent(task)
done = False
labels = ['time', 'x', 'y', 'z', 'phi', 'theta', 'psi', 'x_velocity',
          'y_velocity', 'z_velocity', 'phi_velocity', 'theta_velocity',
          'psi_velocity', 'rotor_speed1', 'rotor_speed2', 'rotor_speed3', 'rotor_speed4']
results = {x : [] for x in labels}

# Run the simulation, and save the results.
with open(file_output, 'w') as csvfile:
    writer = csv.writer(csvfile)
    writer.writerow(labels)
    while True:
        rotor_speeds = agent.act()
        _, _, done = task.step(rotor_speeds)
        to_write = [task.sim.time] + list(task.sim.pose) + list(task.sim.v) + list(task.sim.angular_v) + list(rotor_speeds)
        for ii in range(len(labels)):
            results[labels[ii]].append(to_write[ii])
        writer.writerow(to_write)
        if done:
            break

# %% [markdown]
# Run the code cell below to visualize how the position of the quadcopter evolved during the simulation.

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

plt.plot(results['time'], results['x'], label='x')
plt.plot(results['time'], results['y'], label='y')
plt.plot(results['time'], results['z'], label='z')
plt.legend()
_ = plt.ylim()

# %% [markdown]
# The next code cell visualizes the velocity of the quadcopter.

# %%
plt.plot(results['time'], results['x_velocity'], label='x_hat')
plt.plot(results['time'], results['y_velocity'], label='y_hat')
plt.plot(results['time'], results['z_velocity'], label='z_hat')
plt.legend()
_ = plt.ylim()

# %% [markdown]
# Next, you can plot the Euler angles (the rotation of the quadcopter over the $x$-, $y$-, and $z$-axes),

# %%
plt.plot(results['time'], results['phi'], label='phi')
plt.plot(results['time'], results['theta'], label='theta')
plt.plot(results['time'], results['psi'], label='psi')
plt.legend()
_ = plt.ylim()

# %% [markdown]
# before plotting the velocities (in radians per second) corresponding to each of the Euler angles.

# %%
plt.plot(results['time'], results['phi_velocity'], label='phi_velocity')
plt.plot(results['time'], results['theta_velocity'], label='theta_velocity')
plt.plot(results['time'], results['psi_velocity'], label='psi_velocity')
plt.legend()
_ = plt.ylim()

# %% [markdown]
# Finally, you can use the code cell below to print the agent's choice of actions.

# %%
plt.plot(results['time'], results['rotor_speed1'], label='Rotor 1 revolutions / second')
plt.plot(results['time'], results['rotor_speed2'], label='Rotor 2 revolutions / second')
plt.plot(results['time'], results['rotor_speed3'], label='Rotor 3 revolutions / second')
plt.plot(results['time'], results['rotor_speed4'], label='Rotor 4 revolutions / second')
plt.legend()
_ = plt.ylim()

# %% [markdown]
# When specifying a task, you will derive the environment state from the simulator.  Run the code cell below to print the values of the following variables at the end of the simulation:
# - `task.sim.pose` (the position of the quadcopter in ($x,y,z$) dimensions and the Euler angles),
# - `task.sim.v` (the velocity of the quadcopter in ($x,y,z$) dimensions), and
# - `task.sim.angular_v` (radians/second for each of the three Euler angles).

# %%
# the pose, velocity, and angular velocity of the quadcopter at the end of the episode
print(task.sim.pose)
print(task.sim.v)
print(task.sim.angular_v)
# Out:
# [ -7.82677355 -12.42983648  30.29559811   5.70388999   0.3305048
#    0.        ]
# [-6.32048443 -9.61699096  2.51007428]
# [-0.19370913  0.12913682  0.        ]

# %% [markdown]
# In the sample task in `task.py`, we use the 6-dimensional pose of the quadcopter to construct the state of the environment at each timestep.  However, when amending the task for your purposes, you are welcome to expand the size of the state vector by including the velocity information.  You can use any combination of the pose, velocity, and angular velocity - feel free to tinker here, and construct the state to suit your task.
#
# ## The Task
#
# A sample task has been provided for you in `task.py`.  Open this file in a new window now.
#
# The `__init__()` method is used to initialize several variables that are needed to specify the task.
# - The simulator is initialized as an instance of the `PhysicsSim` class (from `physics_sim.py`).
# - Inspired by the methodology in the original DDPG paper, we make use of action repeats.  For each timestep of the agent, we step the simulation `action_repeats` timesteps.  If you are not familiar with action repeats, please read the **Results** section in [the DDPG paper](https://arxiv.org/abs/1509.02971).
# - We set the number of elements in the state vector.  For the sample task, we only work with the 6-dimensional pose information.  To set the size of the state (`state_size`), we must take action repeats into account.
# - The environment will always have a 4-dimensional action space, with one entry for each rotor (`action_size=4`). You can set the minimum (`action_low`) and maximum (`action_high`) values of each entry here.
# - The sample task in this provided file is for the agent to reach a target position.  We specify that target position as a variable.
#
# The `reset()` method resets the simulator.  The agent should call this method every time the episode ends.  You can see an example of this in the code cell below.
#
# The `step()` method is perhaps the most important.  It accepts the agent's choice of action `rotor_speeds`, which is used to prepare the next state to pass on to the agent.  Then, the reward is computed from `get_reward()`.  The episode is considered done if the time limit has been exceeded, or the quadcopter has travelled outside of the bounds of the simulation.
#
# In the next section, you will learn how to test the performance of an agent on this task.

# %% [markdown]
# ## The Agent
#
# The sample agent given in `agents/policy_search.py` uses a very simplistic linear policy to directly compute the action vector as a dot product of the state vector and a matrix of weights. Then, it randomly perturbs the parameters by adding some Gaussian noise, to produce a different policy. Based on the average reward obtained in each episode (`score`), it keeps track of the best set of parameters found so far, how the score is changing, and accordingly tweaks a scaling factor to widen or tighten the noise.
#
# Run the code cell below to see how the agent performs on the sample task.

# %%
import sys
import pandas as pd
from agents.policy_search import PolicySearch_Agent
from task import Task

num_episodes = 1000
target_pos = np.array([0., 0., 10.])
task = Task(target_pos=target_pos)
agent = PolicySearch_Agent(task)

for i_episode in range(1, num_episodes+1):
    state = agent.reset_episode() # start a new episode
    while True:
        action = agent.act(state) 
        next_state, reward, done = task.step(action)
        agent.step(reward, done)
        state = next_state
        if done:
            print("\rEpisode = {:4d}, score = {:7.3f} (best = {:7.3f}), noise_scale = {}".format(
                i_episode, agent.score, agent.best_score, agent.noise_scale), end="")  # [debug]
            break
    sys.stdout.flush()
# Out:
# /Users/Timothy/Code/RL-Quadcopter-2-master/physics_sim.py:114: RuntimeWarning: invalid value encountered in double_scalars
#   J = V / n * D
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-61-2d7d821a99ef> in <module>()
#      13     while True:
#      14         action = agent.act(state)
# ---> 15         next_state, reward, done = task.step(action)
#      16         agent.step(reward, done)
#      17         state = next_state
#
# ~/Code/RL-Quadcopter-2-master/task.py in step(self, rotor_speeds)
#      78         for _ in range(self.action_repeat):
#      79             done = self.sim.next_timestep(rotor_speeds) # update the sim pose and velocities
# ---> 80             reward += self.get_reward()
#      81             pose_all.append(self.sim.pose)
#      82         next_state = np.concatenate(pose_all)
#
# ~/Code/RL-Quadcopter-2-master/task.py in get_reward(self)
#      44         # Absolute Distance
#      45         current_distance = np.linalg.norm(self.sim.pose[:3] - self.target_pos)
# ---> 46         original_distance = np.linalg.norm(self.target_pos - self.init_pose[:3])
#      47         rewards.append( -1*(current_distance/original_distance if original_distance != 0 else current_distance) )
#      48
#
# TypeError: 'NoneType' object is not subscriptable

# %% [markdown]
# This agent should perform very poorly on this task.  And that's where you come in!

# %% [markdown]
# ## Define the Task, Design the Agent, and Train Your Agent!
#
# Amend `task.py` to specify a task of your choosing.  If you're unsure what kind of task to specify, you may like to teach your quadcopter to takeoff, hover in place, land softly, or reach a target pose.
#
# After specifying your task, use the sample agent in `agents/policy_search.py` as a template to define your own agent in `agents/agent.py`.  You can borrow whatever you need from the sample agent, including ideas on how you might modularize your code (using helper methods like `act()`, `learn()`, `reset_episode()`, etc.).
#
# Note that it is **highly unlikely** that the first agent and task that you specify will learn well.  You will likely have to tweak various hyperparameters and the reward function for your task until you arrive at reasonably good behavior.
#
# As you develop your agent, it's important to keep an eye on how it's performing. Use the code above as inspiration to build in a mechanism to log/save the total rewards obtained in each episode to file.  If the episode rewards are gradually increasing, this is an indication that your agent is learning.

# %%
# PENDULUM AGENT
from agents.agent import MyAgent
import sys
import pandas as pd
from cart_task import Task

num_episodes = 1000
task = Task()
agent = MyAgent(task)

rewards = []
best_reward = -np.inf
for i_episode in range(1, num_episodes+1):
    state = agent.reset_episode() # start a new episode
    current_reward = 0
    while True:
        if i_episode > 900:
            task.env.render()
        action = agent.act(state) 
        next_state, reward, done = task.step(action)
        agent.step(action, reward, next_state, done)
        state = next_state
        current_reward += reward
        if done:
            # Updates best score and results
            if current_reward > best_reward:
                best_reward = current_reward
            rewards.append(current_reward)
            print("\rEpisode = {:4d}, score = {:10.3f}, best score = {:10.3f}".format(i_episode, current_reward, best_reward))
            
            break
    sys.stdout.flush()
# Out:
# WARN: gym.spaces.Box autodetected dtype as <class 'numpy.float32'>. Please provide explicit dtype.
# WARN: gym.spaces.Box autodetected dtype as <class 'numpy.float32'>. Please provide explicit dtype.
# Episode =    1, score =  -1627.519, best score =  -1627.519
# Episode =    2, score =  -1541.508, best score =  -1541.508
# Episode =    3, score =  -1257.108, best score =  -1257.108
# Episode =    4, score =  -1293.105, best score =  -1257.108
# Episode =    5, score =  -1479.626, best score =  -1257.108
# Episode =    6, score =  -1289.520, best score =  -1257.108
# Episode =    7, score =  -1639.069, best score =  -1257.108
# Episode =    8, score =  -1493.518, best score =  -1257.108
# Episode =    9, score =  -1199.063, best score =  -1199.063
# Episode =   10, score =  -1708.344, best score =  -1199.063
# Episode =   11, score =  -1500.867, best score =  -1199.063
# Episode =   12, score =  -1654.774, best score =  -1199.063
# Episode =   13, score =  -1562.617, best score =  -1199.063
# Episode =   14, score =  -1744.758, best score =  -1199.063
# Episode =   15, score =  -1763.033, best score =  -1199.063
# Episode =   16, score =  -1897.689, best score =  -1199.063
# Episode =   17, score =  -1706.549, best score =  -1199.063
# Episode =   18, score =  -1719.438, best score =  -1199.063
# Episode =   19, score =  -1582.136, best score =  -1199.063
# Episode =   20, score =  -1690.201, best score =  -1199.063
# Episode =   21, score =  -1841.954, best score =  -1199.063
# Episode =   22, score =  -1741.263, best score =  -1199.063
# Episode =   23, score =  -1848.373, best score =  -1199.063
# Episode =   24, score =  -1352.839, best score =  -1199.063
# Episode =   25, score =  -1616.761, best score =  -1199.063
# Episode =  547, score =  -1310.692, best score =   -758.458
# Episode =  548, score =  -1188.166, best score =   -758.458
# Episode =  549, score =  -1123.317, best score =   -758.458
# Episode =  550, score =  -1095.399, best score =   -758.458
# Episode =  551, score =  -1172.372, best score =   -758.458
# Episode =  552, score =  -1299.050, best score =   -758.458
# Episode =  553, score =  -1340.335, best score =   -758.458
# Episode =  554, score =  -1022.735, best score =   -758.458
# Episode =  555, score =  -1429.911, best score =   -758.458
# Episode =  556, score =  -1179.766, best score =   -758.458
# Episode =  557, score =  -1291.586, best score =   -758.458
# Episode =  558, score =   -708.041, best score =   -708.041
# Episode =  559, score =   -917.852, best score =   -708.041
# Episode =  560, score =  -1184.500, best score =   -708.041
# Episode =  561, score =  -1162.657, best score =   -708.041
# Episode =  562, score =  -1416.720, best score =   -708.041
# Episode =  563, score =  -1451.166, best score =   -708.041
# Episode =  564, score =  -1494.975, best score =   -708.041
# Episode =  565, score =  -1478.849, best score =   -708.041
# Episode =  566, score =  -1316.904, best score =   -708.041
# Episode =  567, score =  -1484.407, best score =   -708.041
# Episode =  568, score =  -1542.045, best score =   -708.041
# Episode =  569, score =  -1253.485, best score =   -708.041
# Episode =  570, score =  -1369.383, best score =   -708.041
# Episode =  571, score =  -1181.581, best score =   -708.041
# Episode =  572, score =  -1364.679, best score =   -708.041
# Episode =  573, score =  -1181.521, best score =   -708.041
# Episode =  574, score =  -1548.736, best score =   -708.041
# Episode =  575, score =  -1126.712, best score =   -708.041
# Episode =  576, score =  -1026.072, best score =   -708.041
# Episode =  577, score =  -1319.552, best score =   -708.041
# Episode =  578, score =  -1185.052, best score =   -708.041
# Episode =  579, score =  -1267.648, best score =   -708.041
# Episode =  580, score =  -1410.219, best score =   -708.041
# Episode =  581, score =  -1525.453, best score =   -708.041
# Episode =  582, score =  -1545.579, best score =   -708.041
# Episode =  583, score =  -1305.030, best score =   -708.041
# Episode =  584, score =  -1090.842, best score =   -708.041
# Episode =  585, score =  -1261.169, best score =   -708.041
# Episode =  586, score =   -966.441, best score =   -708.041
# Episode =  587, score =  -1039.314, best score =   -708.041
# Episode =  588, score =  -1094.500, best score =   -708.041
# Episode =  589, score =  -1557.187, best score =   -708.041
# Episode =  590, score =  -1533.458, best score =   -708.041
# Episode =  591, score =  -1180.206, best score =   -708.041
# Episode =  592, score =  -1213.345, best score =   -708.041
# Episode =  593, score =  -1552.846, best score =   -708.041
# Episode =  594, score =  -1346.374, best score =   -708.041
# Episode =  595, score =  -1193.599, best score =   -708.041
# Episode =  596, score =  -1325.733, best score =   -708.041
# Episode =  597, score =  -1186.942, best score =   -708.041
# Episode =  598, score =  -1240.316, best score =   -708.041
# Episode =  599, score =  -1325.345, best score =   -708.041
# Episode =  600, score =  -1483.782, best score =   -708.041
# Episode =  601, score =  -1056.721, best score =   -708.041
# Episode =  602, score =  -1105.688, best score =   -708.041
# Episode =  603, score =  -1205.496, best score =   -708.041
# Episode =  604, score =  -1488.293, best score =   -708.041
# Episode =  605, score =  -1443.216, best score =   -708.041
# Episode =  606, score =  -1534.845, best score =   -708.041
# Episode =  607, score =  -1246.194, best score =   -708.041
# Episode =  608, score =  -1465.497, best score =   -708.041
# Episode =  609, score =  -1285.307, best score =   -708.041
# Episode =  610, score =  -1189.417, best score =   -708.041
# Episode =  611, score =  -1473.428, best score =   -708.041
# Episode =  612, score =  -1411.250, best score =   -708.041
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~/miniconda2/envs/UdacityReinforcement/lib/python3.6/site-packages/tensorflow/python/pywrap_tensorflow_internal.py in __init__(self)
#     958         try:
# --> 959             self.this.append(this)
#     960         except Exception:
#
# ~/miniconda2/envs/UdacityReinforcement/lib/python3.6/site-packages/tensorflow/python/pywrap_tensorflow_internal.py in <lambda>(self, name)
#     944     __swig_getmethods__ = {}
# --> 945     __getattr__ = lambda self, name: _swig_getattr(self, TF_Output, name)
#     946     __repr__ = _swig_repr
#
# ~/miniconda2/envs/UdacityReinforcement/lib/python3.6/site-packages/tensorflow/python/pywrap_tensorflow_internal.py in _swig_getattr(self, class_type, name)
#      73 def _swig_getattr(self, class_type, name):
# ---> 74     return _swig_getattr_nondynamic(self, class_type, name, 0)
#      75
#
# ~/miniconda2/envs/UdacityReinforcement/lib/python3.6/site-packages/tensorflow/python/pywrap_tensorflow_internal.py in _swig_getattr_nondynamic(self, class_type, name, static)
#      68     if (not static):
# ---> 69         return object.__getattr__(self, name)
#      70     else:
#
# AttributeError: type object 'object' has no attribute '__getattr__'
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-5-9ad52279f46c> in <module>()
#      19         action = agent.act(state)
#      20         next_state, reward, done = task.step(action)
# ---> 21         agent.step(action, reward, next_state, done)
#      22         state = next_state
#      23         current_reward += reward
#
# ~/Code/RL-Quadcopter-2-master/agents/agent.py in step(self, action, reward, next_state, done)
#      47         if len(self.memory) > self.batch_size:
#      48             experiences = self.memory.sample()
# ---> 49             self.learn(experiences)
#      50
#      51         self.last_state = next_state
#
# ~/Code/RL-Quadcopter-2-master/agents/agent.py in learn(self, experiences)
#      68
#      69         self.soft_update(self.critic_local.model, self.critic_target.model)
# ---> 70         self.soft_update(self.actor_local.model, self.actor_target.model)
#      71
#      72     def reset_episode(self):
#
# ~/Code/RL-Quadcopter-2-master/agents/agent.py in soft_update(self, local_model, target_model)
#      84
#      85         new_weights = self.tau * local_weights + (1-self.tau) * target_weights
# ---> 86         target_model.set_weights(new_weights)
#      87
#      88
#
# ~/miniconda2/envs/UdacityReinforcement/lib/python3.6/site-packages/keras/engine/topology.py in set_weights(self, weights)
#    2029                 tuples.append((sw, w))
#    2030             weights = weights[num_param:]
# -> 2031         K.batch_set_value(tuples)
#    2032
#    2033     @property
#
# ~/miniconda2/envs/UdacityReinforcement/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py in batch_set_value(tuples)
#    2375             assign_ops.append(assign_op)
#    2376             feed_dict[assign_placeholder] = value
# -> 2377         get_session().run(assign_ops, feed_dict=feed_dict)
#    2378
#    2379
#
# ~/miniconda2/envs/UdacityReinforcement/lib/python3.6/site-packages/tensorflow/python/client/session.py in run(self, fetches, feed_dict, options, run_metadata)
#     898     try:
#     899       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 900                          run_metadata_ptr)
#     901       if run_metadata:
#     902         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# ~/miniconda2/envs/UdacityReinforcement/lib/python3.6/site-packages/tensorflow/python/client/session.py in _run(self, handle, fetches, feed_dict, options, run_metadata)
#    1133     if final_fetches or final_targets or (handle and feed_dict_tensor):
#    1134       results = self._do_run(handle, final_targets, final_fetches,
# -> 1135                              feed_dict_tensor, options, run_metadata)
#    1136     else:
#    1137       results = []
#
# ~/miniconda2/envs/UdacityReinforcement/lib/python3.6/site-packages/tensorflow/python/client/session.py in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1293       # pylint: disable=protected-access
#    1294       feeds = dict((t._as_tf_output(), v) for t, v in feed_dict.items())
# -> 1295       fetches = [t._as_tf_output() for t in fetch_list]
#    1296       targets = [op._c_op for op in target_list]
#    1297       # pylint: enable=protected-access
#
# ~/miniconda2/envs/UdacityReinforcement/lib/python3.6/site-packages/tensorflow/python/client/session.py in <listcomp>(.0)
#    1293       # pylint: disable=protected-access
#    1294       feeds = dict((t._as_tf_output(), v) for t, v in feed_dict.items())
# -> 1295       fetches = [t._as_tf_output() for t in fetch_list]
#    1296       targets = [op._c_op for op in target_list]
#    1297       # pylint: enable=protected-access
#
# ~/miniconda2/envs/UdacityReinforcement/lib/python3.6/site-packages/tensorflow/python/framework/ops.py in _as_tf_output(self)
#     599     # pylint: disable=protected-access
#     600     assert self.op._c_op
# --> 601     return c_api_util.tf_output(self.op._c_op, self.value_index)
#     602     # pylint: enable=protected-access
#     603
#
# ~/miniconda2/envs/UdacityReinforcement/lib/python3.6/site-packages/tensorflow/python/framework/c_api_util.py in tf_output(c_op, index)
#     133     Wrapped TF_Output
#     134   """
# --> 135   ret = c_api.TF_Output()
#     136   ret.oper = c_op
#     137   ret.index = index
#
# ~/miniconda2/envs/UdacityReinforcement/lib/python3.6/site-packages/tensorflow/python/pywrap_tensorflow_internal.py in __init__(self)
#     959             self.this.append(this)
#     960         except Exception:
# --> 961             self.this = this
#     962     __swig_destroy__ = _pywrap_tensorflow_internal.delete_TF_Output
#     963     __del__ = lambda self: None
#
# ~/miniconda2/envs/UdacityReinforcement/lib/python3.6/site-packages/tensorflow/python/pywrap_tensorflow_internal.py in <lambda>(self, name, value)
#     941 class TF_Output(_object):
#     942     __swig_setmethods__ = {}
# --> 943     __setattr__ = lambda self, name, value: _swig_setattr(self, TF_Output, name, value)
#     944     __swig_getmethods__ = {}
#     945     __getattr__ = lambda self, name: _swig_getattr(self, TF_Output, name)
#
# KeyboardInterrupt:

# %%
## TODO: Train your agent here.
from agents.agent import MyAgent
import sys
import pandas as pd
from task import Task
# from cart_task import Task

num_episodes = 1000
init_pose = np.array([0., 0., 1., 0., 0., 0.])
target_pos = np.array([0., 0., 10.])
task = Task(init_pose=init_pose, target_pos=target_pos)
# task = Task()
agent = MyAgent(task)
labels = ['time', 'x', 'y', 'z', 'phi', 'theta', 'psi', 'x_velocity',
          'y_velocity', 'z_velocity', 'phi_velocity', 'theta_velocity',
          'psi_velocity', 'rotor_speed1', 'rotor_speed2', 'rotor_speed3', 'rotor_speed4']
results = {x : [] for x in labels}

rewards = []
best_reward = -np.inf
for i_episode in range(1, num_episodes+1):
    state = agent.reset_episode() # start a new episode
    current_reward = 0
    new_results = {x : [] for x in labels} # New temporary results
    while True:
        action = agent.act(state) 
        next_state, reward, done = task.step(action)
        agent.step(action, reward, next_state, done)
        state = next_state
        current_reward += reward
        # Adds simulation information to new_results
        to_write = [task.sim.time] + list(task.sim.pose) + list(task.sim.v) + list(task.sim.angular_v) + list(rotor_speeds)
        for ii in range(len(labels)):
            new_results[labels[ii]].append(to_write[ii])
        if done:
            # Updates best score and results
            if current_reward > best_reward:
                best_reward = current_reward
            results = new_results
            rewards.append(current_reward)
            print("\rEpisode = {:4d}, reward = {:7.3f}, best reward = {:7.3f}, time = {:7.3f}, avg = {:7.3f}".format(
                i_episode, current_reward, best_reward, task.sim.time, task.reward_avg))   # [debug]
            
            break
    sys.stdout.flush()
# Out:
# Episode =    1, reward = -12.857, best reward = -12.857, time =   5.040, avg =  -0.056
# Episode =    2, reward =  -1.690, best reward =  -1.690, time =   5.040, avg =  -0.007
# Episode =    3, reward =  58.597, best reward =  58.597, time =   5.040, avg =   0.233
# Episode =    4, reward =  76.360, best reward =  76.360, time =   5.040, avg =   0.303
# Episode =    5, reward = -24.553, best reward =  76.360, time =   4.860, avg =  -0.144
# Episode =    6, reward =   5.868, best reward =  76.360, time =   5.040, avg =   0.023
# Episode =    7, reward = -25.146, best reward =  76.360, time =   5.040, avg =  -0.136
# Episode =    8, reward =  33.781, best reward =  76.360, time =   5.040, avg =   0.134
# Episode =    9, reward =  17.407, best reward =  76.360, time =   5.040, avg =   0.069
# Episode =   10, reward = -16.521, best reward =  76.360, time =   4.500, avg =  -0.101
# Episode =   11, reward = -34.818, best reward =  76.360, time =   5.040, avg =  -0.210
# Episode =   12, reward =  27.194, best reward =  76.360, time =   5.040, avg =   0.108
# Episode =   13, reward =  43.960, best reward =  76.360, time =   5.040, avg =   0.174
# Episode =   14, reward =  21.515, best reward =  76.360, time =   5.040, avg =   0.085
# Episode =   15, reward =  11.206, best reward =  76.360, time =   5.040, avg =   0.044
# Episode =   16, reward =  29.109, best reward =  76.360, time =   5.040, avg =   0.116
# Episode =   17, reward =  23.688, best reward =  76.360, time =   5.040, avg =   0.094
# Episode =   93, reward =  36.147, best reward =  82.537, time =   5.040, avg =   0.143
# Episode =   94, reward =  37.244, best reward =  82.537, time =   5.040, avg =   0.148
# Episode =   95, reward =  52.048, best reward =  82.537, time =   5.040, avg =   0.207
# Episode =   96, reward = -23.570, best reward =  82.537, time =   4.860, avg =  -0.152
# Episode =   97, reward =  37.344, best reward =  82.537, time =   5.040, avg =   0.148
# Episode =   98, reward =  25.144, best reward =  82.537, time =   5.040, avg =   0.100
# Episode =   99, reward = -31.218, best reward =  82.537, time =   5.040, avg =  -0.169
# Episode =  100, reward =  62.706, best reward =  82.537, time =   5.040, avg =   0.249
# Episode =  101, reward =  41.176, best reward =  82.537, time =   5.040, avg =   0.163
# Episode =  102, reward =  -7.638, best reward =  82.537, time =   5.040, avg =  -0.038
# Episode =  103, reward =  33.283, best reward =  82.537, time =   5.040, avg =   0.132
# Episode =  104, reward =  53.587, best reward =  82.537, time =   5.040, avg =   0.213
# Episode =  105, reward =  27.460, best reward =  82.537, time =   5.040, avg =   0.109
# Episode =  106, reward = -21.918, best reward =  82.537, time =   4.260, avg =  -0.127
# Episode =  107, reward =  21.810, best reward =  82.537, time =   5.040, avg =   0.087
# Episode =  108, reward =  40.397, best reward =  82.537, time =   5.040, avg =   0.160
# Episode =  109, reward =  15.719, best reward =  82.537, time =   5.040, avg =   0.062
# Episode =  110, reward =  -1.993, best reward =  82.537, time =   5.040, avg =  -0.009
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-62-2032b6c9dcc4> in <module>()
#      26         action = agent.act(state)
#      27         next_state, reward, done = task.step(action)
# ---> 28         agent.step(action, reward, next_state, done)
#      29         state = next_state
#      30         current_reward += reward
#
# ~/Code/RL-Quadcopter-2-master/agents/agent.py in step(self, action, reward, next_state, done)
#      47         if len(self.memory) > self.batch_size:
#      48             experiences = self.memory.sample()
# ---> 49             self.learn(experiences)
#      50
#      51         self.last_state = next_state
#
# ~/Code/RL-Quadcopter-2-master/agents/agent.py in learn(self, experiences)
#      67         self.actor_local.train_fn([states, action_gradients, 1])
#      68
# ---> 69         self.soft_update(self.critic_local.model, self.critic_target.model)
#      70         self.soft_update(self.actor_local.model, self.actor_target.model)
#      71
#
# ~/Code/RL-Quadcopter-2-master/agents/agent.py in soft_update(self, local_model, target_model)
#      78
#      79     def soft_update(self, local_model, target_model):
# ---> 80         local_weights = np.array(local_model.get_weights())
#      81         target_weights = np.array(target_model.get_weights())
#      82
#
# ~/miniconda2/envs/UdacityReinforcement/lib/python3.6/site-packages/keras/engine/topology.py in get_weights(self)
#    2013         for layer in self.layers:
#    2014             weights += layer.weights
# -> 2015         return K.batch_get_value(weights)
#    2016
#    2017     def set_weights(self, weights):
#
# ~/miniconda2/envs/UdacityReinforcement/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py in batch_get_value(ops)
#    2325     """
#    2326     if ops:
# -> 2327         return get_session().run(ops)
#    2328     else:
#    2329         return []
#
# ~/miniconda2/envs/UdacityReinforcement/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py in get_session()
#     185             candidate_vars = []
#     186             for v in variables:
# --> 187                 if not getattr(v, '_keras_initialized', False):
#     188                     candidate_vars.append(v)
#     189             if candidate_vars:
#
# KeyboardInterrupt:

# %%
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
# %matplotlib inline 

plt.plot(results['time'], results['x'], label='x')
plt.plot(results['time'], results['y'], label='y')
plt.plot(results['time'], results['z'], label='z')
plt.legend()
_ = plt.ylim()

# %%
plt.plot(results['time'], results['x_velocity'], label='x_hat')
plt.plot(results['time'], results['y_velocity'], label='y_hat')
plt.plot(results['time'], results['z_velocity'], label='z_hat')
plt.legend()
_ = plt.ylim()

# %%
plt.plot(results['time'], results['phi'], label='phi')
plt.plot(results['time'], results['theta'], label='theta')
plt.plot(results['time'], results['psi'], label='psi')
plt.legend()
_ = plt.ylim()

# %% [markdown]
# ## Plot the Rewards
#
# Once you are satisfied with your performance, plot the episode rewards, either from a single run, or averaged over multiple runs.

# %%
## TODO: Plot the rewards.
plt.plot(rewards[::1])

# %% [markdown]
# ## Reflections
#
# **Question 1**: Describe the task that you specified in `task.py`.  How did you design the reward function?
#
# **Answer**:

# %% [markdown]
# **Question 2**: Discuss your agent briefly, using the following questions as a guide:
#
# - What learning algorithm(s) did you try? What worked best for you?
# - What was your final choice of hyperparameters (such as $\alpha$, $\gamma$, $\epsilon$, etc.)?
# - What neural network architecture did you use (if any)? Specify layers, sizes, activation functions, etc.
#
# **Answer**:

# %% [markdown]
# **Question 3**: Using the episode rewards plot, discuss how the agent learned over time.
#
# - Was it an easy task to learn or hard?
# - Was there a gradual learning curve, or an aha moment?
# - How good was the final performance of the agent? (e.g. mean rewards over the last 10 episodes)
#
# **Answer**:

# %% [markdown]
# **Question 4**: Briefly summarize your experience working on this project. You can use the following prompts for ideas.
#
# - What was the hardest part of the project? (e.g. getting started, plotting, specifying the task, etc.)
# - Did you find anything interesting in how the quadcopter or your agent behaved?
#
# **Answer**:
